# %%
import sys
module_path = '../preprocess' 
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import joblib

# %%
figpath = ''

# %%
tap2_etas = joblib.load('../data/wt/ETAs/tap2-eta_traces_unzscored.pkl')

# %%
ETAs, ETA_stds, ETA_sems, all_traces = tap2_etas

# %%
from leaprig import WT_DATA
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from leaprig import WT_DATA
#
# File ~/femaleflystates/preprocess/leaprig.py:5
#       2 import numpy as np
#       3 import h5py
# ----> 5 from preprocess import visual_features, tactile_features
#       6 from preprocess.preproc_utils import h5read
#       7 from preprocess import preproc_utils
#
# ModuleNotFoundError: No module named 'preprocess'

# %%
DATA = WT_DATA
event_window = DATA.event_window
before_event_window = DATA.before_event_window
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 DATA = WT_DATA
#       2 event_window = DATA.event_window
#       3 before_event_window = DATA.before_event_window
#
# NameError: name 'WT_DATA' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(event_window/DATA.fps, plot_traces.T, alpha=alpha)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plt.plot(event_window/DATA.fps, plot_traces.T, alpha=alpha)
#
# NameError: name 'event_window' is not defined
